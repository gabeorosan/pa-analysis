# %%
import json

with open('pa-data-nasir.json', 'r') as f:
    data = json.load(f)

fams = data['filters']['family']

gens = data['filters']['genus']

tnums = data['filters']['tnumber']

genomes = data['filters']['genome']

reslist = []

filters = {'family': fams, 'genus': gens,'tnumber': tnums,'genome': genomes}

# %%
1 + [1,2,3]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [165], in <cell line: 1>()
# ----> 1 1 + [1,2,3]
#
# TypeError: unsupported operand type(s) for +: 'int' and 'list'

# %%
def mapg(g):
    if 'ssRNA' in g: return 'ssRNA'
    elif g == 'circular DNA' : return 'dsDNA'
    else: return g

res_tups = []
ids = []
reslist = []
for e in el_lists:
    e[3] = mapg(e[3])
    if e[:4] not in reslist:
        reslist.append(e[:4])
        k = e[4]
        res = float(id_res[k] if k in id_res and id_res[k] is not None else 999)
        res_tups.append((res, e))
        ids.append(k)

for i in range(len(reslist)):
    reslist[i].extend([ids[i]])

# %%
with open('res.txt', 'r') as f:
    id_res = {l.split()[0]:l.split()[1] for l in f}

# %%
el_lists = []
for k in data['data']:
    el = data['data'][k]
    if 'family' in el.keys() and 'genome' in el.keys() and 'genus' in el.keys() and 'tnumber' in el.keys():
        el_lists.append([el['family'], el['genus'], el['tnumber'], el['genome'], k])
        
el_lists_red = [e[:4] for e in el_lists]

def find_best(tup_list, el):
    first = True
    blist = []
    for t in tup_list:
        res = t[0]
        inf = t[1]
        if inf[:-1] == el[:-1]:
            if first or res < best[-1]: 
                best = inf + [res]
                first = False
    return best

# %%
res_tups
# Out:
# [(1.81, ['Virtovirus', 'Tobacco virtovirus 1', '1', 'ssRNA', '1a34']),
#  (3.5, ['Secoviridae', 'Nepovirus', 'pT3', 'ssRNA', '1a6c']),
#  (3.5, ['Microviridae', 'Microvirus', '1', 'ssDNA', '1al0']),
#  (2.9, ['Picornaviridae', 'Enterovirus C', 'pT3', 'ssRNA', '1al2']),
#  (2.8, ['Leviviridae', 'Levivirus', '3', 'ssRNA', '1aq3']),
#  (3.2, ['Tymoviridae', 'Tymovirus', '3', 'ssRNA', '1auy']),
#  (2.15, ['Picornaviridae', 'Rhinovirus', 'pT3', 'ssRNA', '1aym']),
#  (2.4, ['Dicistroviridae', 'Cripavirus', 'pT3', 'ssRNA', '1b35']),
#  (2.6, ['Picornaviridae', 'Aphthovirus', 'pT3', 'ssRNA', '1bbt']),
#  (3.0, ['Picornaviridae', 'Enterovirus', 'pT3', 'ssRNA', '1bev']),
#  (3.0, ['Secoviridae', 'Comovirus', 'pT3', 'ssRNA', '1bmv']),
#  (3.0, ['Parvoviridae', 'Parvovirus', '1', 'ssDNA', '1c8d']),
#  (2.25, ['Tombusviridae', 'Necrovirus', '3', 'ssRNA', '1c8n']),
#  (3.2, ['Bromoviridae', 'Bromovirus', '3', 'ssRNA', '1cwp']),
#  (3.6, ['Parvoviridae', 'Densovirus', '1', 'ssDNA', '1dnv']),
#  (9.0, ['Togaviridae', 'Alphavirus', '4', 'ssRNA', '1dyl']),
#  (3.5, ['Papillomaviridae', 'Alphapapillomavirus', '1', 'dsDNA', '1dzl']),
#  (3.6, ['Reoviridae', 'Orthoreovirus', '2', 'dsRNA', '1ej6']),
#  (3.2, ['Bromoviridae', 'Cucumovirus', '3', 'ssRNA', '1f15']),
#  (2.8, ['Sobemovirus', 'Sobemovirus', '3', 'ssRNA', '1f2n']),
#  (3.0, ['Nodaviridae', 'Alphanodavirus', '3', 'ssRNA', '1f8v']),
#  (3.3, ['Parvoviridae', 'Parvovirus', '1', 'ssRNA', '1fpv']),
#  (13.5, ['Tectiviridae', 'Tectivirus', 'pT25', 'dsDNA', '1gw7']),
#  (12.0, ['Siphoviridae', 'Lambdavirus', '7l', 'dsDNA', '1if0']),
#  (3.4, ['Caliciviridae', 'Norovirus', '3', 'ssRNA', '1ihm']),
#  (24.0, ['Flaviviridae', 'Flavivirus', '3', 'ssRNA', '1k4r']),
#  (999.0, ['Papillomaviridae', 'Alphapapillomavirus', '7d', 'dsDNA', '1l0t']),
#  (3.0, ['Parvoviridae', 'Dependoparvovirus', '1', 'ssDNA', '1lp3']),
#  (3.5, ['Totiviridae', 'Totivirus', '2', 'dsRNA', '1m1c']),
#  (28.0, ['Phycodnaviridae', 'Chlorovirus', 'pT169', 'dsDNA', '1m4x']),
#  (3.2, ['Picornaviridae', 'Cardiovirus', 'pT3', 'ssRNA', '1mec']),
#  (16.0, ['Flaviviridae', 'Flavivirus', '3', 'ssDNA', '1n6g']),
#  (2.8, ['Tetraviridae', 'Omegatetravirus', '4', 'ssRNA', '1ohf']),
#  (3.2, ['Tombusviridae', 'Carmovirus', '3', 'ssRNA', '1opo']),
#  (3.5, ['Leviviridae', 'Allolevivirus', '3', 'ssRNA', '1qbe']),
#  (3.3, ['Hepadnaviridae', 'Orthohepadnavirus', '4', 'dsDNA', '1qgt']),
#  (3.65, ['Polyomaviridae', 'Polyomavirus', '7d', 'dsDNA', '1sid']),
#  (1.9, ['Papanivirus', 'Panicum papanivirus 1', '1', '', '1stm']),
#  (3.5, ['Reoviridae', 'Phytoreovirus', '13', 'dsRNA', '1uf2']),
#  (3.05, ['Sobemovirus', 'Sobemovirus', '1', 'ssRNA', '1vak']),
#  (3.0, ['Birnaviridae', 'Avibirnavirus', '1', 'dsRNA', '1wcd']),
#  (7.0, ['Birnaviridae', 'Avibirnavirus', '13', 'dsRNA', '1wce']),
#  (3.3, ['Adenoviridae', 'Mastadenovirus', '1', 'dsDNA', '1x9p']),
#  (2.9, ['Bromoviridae', 'Bromovirus', '1', 'ssRNA', '1yc6']),
#  (7.9, ['Podoviridae', 'Phi29virus', '3', 'dsDNA', '1yxn']),
#  (3.25, ['Parvoviridae', 'Parvovirus', '1', '', '1z14']),
#  (3.5, ['Parvoviridae', 'Protoparvovirus', '1', 'ssDNA', '1z1c']),
#  (3.5, ['Reoviridae', 'Orbivirus', '13', 'dsRNA', '2btv']),
#  (2.45, ['Albetovirus', 'Tobacco albetovirus 1', '1', 'ssRNA', '2buk']),
#  (7.0, ['Reoviridae', 'Orthoreovirus', '13', 'dsRNA', '2cse']),
#  (3.6, ['Thermococcales', 'Pyrococcus', '3', 'ssDNA', '2e0z']),
#  (3.2, ['Caliciviridae', 'Vesivirus', '3', 'ssRNA', '2gh8']),
#  (3.8, ['Tetraviridae', 'Betatetravirus', '4', 'ssRNA', '2qqp']),
#  (2.5, ['Albetovirus', 'Tobacco albetovirus 1', '1', '', '2stv']),
#  (2.9, ['Tombusviridae', 'Tombusvirus', '3', 'ssRNA', '2tbv']),
#  (3.4, ['Picobirnaviridae', 'Picobirnavirus', '2', 'dsRNA', '2vf1']),
#  (3.5, ['Leviviridae', 'Unclassified', '3', 'ssRNA', '2vf9']),
#  (7.0, ['Corticoviridae', 'Corticovirus', 'pT21', 'dsDNA', '2w0c']),
#  (18.3, ['Retroviridae', 'Alpharetrovirus', '1', 'ssRNA', '2x8q']),
#  (4.6, ['Podoviridae', 'unassigned Autographivirinae', '7l', 'dsDNA', '2xd8']),
#  (10.8, ['Podoviridae', 'T7virus', '7l', 'dsDNA', '2xvr']),
#  (3.8, ['Podoviridae', 'P22-like viruses', '7l', 'dsDNA', '2xyy']),
#  (3.56, ['Hepeviridae', 'Orthohepevirus', '1', 'ssRNA', '2ztn']),
#  (4.5, ['Podoviridae', 'p22-like Viruses', '7l', 'dsDNA', '3c5b']),
#  (2.3, ['Picornaviridae', 'Senecavirus', 'pT3', 'ssRNA', '3cji']),
#  (3.88, ['Reoviridae', 'Cypovirus', '2', 'dsRNA', '3cnf']),
#  (3.3, ['Partitiviridae', 'Partitivirus', '2', 'dsRNA', '3es5']),
#  (3.8, ['Reoviridae', 'Rotavirus', '13', 'dsRNA', '3gzt']),
#  (3.8, ['Reoviridae', 'Rotavirus', '', 'dsRNA', '3gzu']),
#  (3.35, ['Birnaviridae', 'Aquabirnavirus', '1', 'dsRNA', '3ide']),
#  (8.2, ['Podoviridae', 'P22-like Viruses', '7l', 'dsDNA', '3iyh']),
#  (4.2, ['Papillomaviridae', 'Deltapapillomavirus', '7d', 'dsDNA', '3iyj']),
#  (3.3, ['Reoviridae', 'Aquareovirus', '2', 'dsDNA', '3iyl']),
#  (10.5, ['Hepeviridae', 'Orthohepevirus', '3', 'ssRNA', '3iyo']),
#  (3.9, ['Reoviridae', 'Reovirus', '', 'dsRNA', '3iz3']),
#  (4.1, ['Reoviridae', 'Cypovirus', '1', 'dsRNA', '3j17']),
#  (6.5, ['Caliciviridae', 'Lagovirus', '3', 'ssRNA', '3j1p']),
#  (3.5, ['Lavidaviridae', 'Sputnikvirus', 'pT27', 'dsDNA', '3j26']),
#  (4.5, ['Turriviridae', 'Alphaturrivirus', 'pT31', 'dsDNA', '3j31']),
#  (4.1, ['Chrysoviridae', 'Chrysovirus', '1', 'dsRNA', '3j3i']),
#  (4.5, ['Podoviridae', 'Epsilon15-like', '7l', 'dsDNA', '3j40']),
#  (3.5, ['Podoviridae', 'Bpp1virus', '7l', 'dsDNA', '3j4u']),
#  (3.1, ['Reoviridae', 'Cypovirus', '', 'dsRNA', '3jaz']),
#  (3.8, ['Picornaviridae', 'Parechovirus', 'pT3', 'ssRNA', '3jb4']),
#  (3.6, ['Tombusviridae', 'Machlomovirus', '3', 'ssRNA', '3jb8']),
#  (3.9, ['Nodaviridae', 'Betanodavirus', '3', 'ssRNA', '3jbm']),
#  (2.9, ['Circoviridae', 'Circovirus', '1', 'ssDNA', '3jci']),
#  (4.5, ['Reoviridae', 'Aquareovirus', '', 'dsDNA', '3k1q']),
#  (3.4, ['Caliciviridae', 'Calicivirus', '3', 'ssRNA', '3m8l']),
#  (2.5, ['Parvoviridae', 'Penstyldensovirus', '1', 'ssDNA', '3n7x']),
#  (4.5, ['Adenoviridae', 'Mastadenovirus', 'pT25', 'dsDNA', '3zif']),
#  (4.4, ['Cystoviridae', 'Cystovirus', '2', 'dsRNA', '4btg']),
#  (7.5, ['Cystoviridae', 'Cystovirus', '13', 'dsRNA', '4btq']),
#  (3.5, ['Parvoviridae', 'Ambidensovirus', '1', 'ssDNA', '4mgu']),
#  (3.25, ['Nodaviridae', 'Unclassified', '3', 'ssRNA', '4nwv']),
#  (8.0, ['Caliciviridae', 'Vesivirus', '1', 'ssRNA', '4pb6']),
#  (4.6, ['Nanoparticles', 'Nanoparticles', '3', 'NA', '4pt2']),
#  (3.2, ['Parvoviridae', 'Bocaparvovirus', '1', 'ssDNA', '4qc8']),
#  (3.5, ['Picornaviridae', 'Hepatovirus', '3', 'ssRNA', '4qpg']),
#  (3.1, ['Nodaviridae', 'Betanodavirus', '1', 'ssRNA', '4rft']),
#  (1.45, ['Albetovirus', 'Tobacco albetovirus 1', '1', 'NA', '4v4m']),
#  (2.9, ['Tombusviridae', 'Panicovirus', '3', 'ssRNA', '4v99']),
#  (3.8, ['Picornaviridae', 'Enterovirus A', 'pT3', 'ssRNA', '4yvw']),
#  (2.2, ['Leviviridae', 'Levivirus', '1', 'ssRNA', '4zor']),
#  (2.1, ['Picornaviridae', 'Kobuvirus', 'pT3', 'ssRNA', '5aoo']),
#  (4.0, ['Dicistroviridae', 'Aparavirus', 'pT3', 'ssRNA', '5cdc']),
#  (3.3, ['Papanivirus', 'Panicum papanivirus 1', '1', 'ssRNA', '5cvz']),
#  (3.8, ['Iflaviridae', 'Iflavirus', 'pT3', 'ssRNA', '5g52']),
#  (2.89, ['Podoviridae', 'P22virus', '7l', 'dsDNA', '5l35']),
#  (2.7, ['Unclassified', 'Unclassified', 'pT3', 'ssRNA', '5mm2']),
#  (3.4, ['Dicistroviridae', 'Triatovirus', 'pT3', 'ssRNA', '5mqc']),
#  (4.0, ['Unknown', 'Unknown', 'pT21', 'dsDNA', '5oac']),
#  (3.3, ['Myoviridae', 'T4virus', '13', 'dsDNA', '5vf3']),
#  (3.4, ['Picornaviridae', 'Hepatovirus', 'pT3', 'ssRNA', '5wte']),
#  (3.12, ['Nodaviridae', 'Unclassified', '1', 'ssRNA', '5yl1']),
#  (3.1, ['Herpesviridae', 'Alphaherpesvirinae', '16', 'dsDNA', '5zap']),
#  (3.3, ['Reoviridae', 'Aquareovirus', '1', 'dsRNA', '5zvt']),
#  (3.8, ['Siphoviridae', 'Phietavirus', '7l', 'dsDNA', '6b0x']),
#  (3.7, ['Siphoviridae', 'Phietavirus', '4', 'dsDNA', '6b23']),
#  (4.2, ['Herpesviridae', 'Rhadinovirus', '16', 'dsDNA', '6b43']),
#  (4.0, ['Hepadnaviridae', 'Orthohepadnavirus', '3', 'dsDNA', '6bvn']),
#  (8.4, ['Siphoviridae', 'Phietavirus', '4', 'ssDNA', '6c22']),
#  (3.8, ['Adenoviridae', 'Mastadenovirus', 'pT25', 'ssDNA', '6cgv']),
#  (3.9, ['Reoviridae', 'Dinovernavirus', '1', 'dsRNA', '6djy']),
#  (4.24, ['Polyomaviridae', 'Betapolyomavirus', '7d', 'dsDNA', '6gg0']),
#  (3.78,
#   ['Sphaerolipoviridae', 'Alphasphaerolipovirus', '28d', 'dsDNA', '6h82']),
#  (3.74, ['Siphoviridae', 'P23virus', '7l', 'dsDNA', '6i9e']),
#  (2.5, ['Nanoparticles', 'Nanoparticles', '1', 'NA', '6i9g']),
#  (3.3, ['Unclassified', 'Unclassified', '3', 'ssRNA', '6izl']),
#  (3.53, ['Siphoviridae', 'Cyanophage Mic1', '13', 'dsDNA', '6j3q']),
#  (3.18, ['Parvoviridae', 'Denpendoparvovirus', '1', 'ssDNA', '6jct']),
#  (2.91, ['Sarthroviridae', 'Macronovirus', '1', 'ssRNA', '6jja']),
#  (2.92, ['Nodaviridae', 'Unclassified Nodaviridae', '3', 'ssRNA', '6jjc']),
#  (2.32, ['Picornaviridae', 'Enterovirus B', 'pT3', 'ssRNA', '6la3']),
#  (3.2, ['Tombusviridae', 'Aureusvirus', '3', 'ssRNA', '6mrl']),
#  (2.9, ['Tombusviridae', 'Dianthovirus', '3', 'ssRNA', '6mrm']),
#  (3.0, ['Nanoparticles', 'Nanoparticles', '9', 'NA', '6mzx']),
#  (3.5, ['Phycodnaviridae', 'Chlorovirus', '169', 'dsDNA', '6ncl']),
#  (3.89, ['Parvoviridae', 'Virus Like Particle', '1', 'ssDNA', '6nf9']),
#  (5.0, ['Herpesviridae', 'Muromegalovirus', '16', 'dsDNA', '6nhj']),
#  (3.22, ['Parvoviridae', 'Erythroparvovirus', '1', 'ssDNA', '6nn3']),
#  (2.8, ['Siphoviridae', 'Oshimavirus', '7l', 'dsDNA', '6o3h']),
#  (2.75, ['Parvoviridae', 'Dependoparvovirus', '1', 'dsDNA', '6o9r']),
#  (3.7, ['Protogloboviridae', 'Alphaprotoglobovirus', '43', 'dsDNA', '6oj0']),
#  (6.7, ['Siphoviridae', 'Tequintavirus', '13', 'dsDNA', '6okb']),
#  (2.8, ['Caliciviridae', 'Norovirus', '1', 'ssRNA', '6ouc']),
#  (4.1, ['Caliciviridae', 'Norovirus', '4', 'ssRNA', '6ouu']),
#  (9.0, ['Herpesviridae', 'Betaherpesvirinae', '16', 'dsDNA', '6q1f']),
#  (3.4, ['Adenoviridae', 'Atadenovirus', 'pT25', 'dsDNA', '6qi5']),
#  (7.5, ['Saccharomycetales', 'Saccharomyces', '9', 'ssRNA', '6r24']),
#  (4.0, ['Siphoviridae', 'Unclassified Siphovirus', '7l', 'dsDNA', '6r3a']),
#  (6.0, ['Leviviridae', 'Levivirus', '4', 'ssRNA', '6rrt']),
#  (3.2, ['dsRNA viruses', 'Unclassified', '1', 'dsRNA', '6s2c']),
#  (3.19, ['Nanoviridae', 'Nanovirus', '1', 'ssRNA', '6s44']),
#  (3.0, ['Luteoviridae', 'Luteovirus', '3', 'ssRNA', '6scl']),
#  (3.3, ['Luteoviridae', 'Polerovirus', '3', 'ssRNA', '6sco']),
#  (3.1, ['Marnaviridae', 'Sogarnavirus', 'pT3', 'ssRNA', '6shl']),
#  (2.75, ['Retroviridae', 'Unclassified', '1', 'ssRNA', '6ssj']),
#  (4.34, ['Retroviridae', 'Unclassified', '3', 'ssRNA', '6ssm']),
#  (1.67, ['Picornaviridae', 'Enterovirus F', 'pT3', 'ssRNA', '6t40']),
#  (3.5, ['Unclassified', 'Unclassified', '4', 'NA', '6tap']),
#  (2.23, ['Picornaviridae', 'Enterovirus E', 'pT3', 'ssRNA', '6thd']),
#  (4.03, ['Rhodobacterales', 'Rhodobacteraceae', '3', 'NA', '6tsw']),
#  (5.5, ['Herpesviridae', 'Gammaherpesvirinae', '16', 'dsDNA', '6w19']),
#  (2.9, ['Picornaviridae', 'Enterovirus D', 'pT3', 'ssRNA', '6wds']),
#  (2.2, ['Synechococcaceae', 'Synechococcus', '1', 'NA', '6x8m']),
#  (3.8, ['Unclassified', 'Unclassified', '7l', 'dsDNA', '6xgq']),
#  (3.65, ['Totiviridae', 'Leishmaniavirus', '1', 'dsRNA', '6y83']),
#  (3.4, ['Leviviridae', 'MS2-like capsids', '3', 'ssRNA', '6yf7']),
#  (3.59, ['Leviviridae', 'MS2-like capsids', '1', 'ssRNA', '6yfb']),
#  (3.7, ['Hepadnaviridae', 'Avihepadnavirus', '4', 'dsDNA', '6ygh']),
#  (3.52, ['Polyomaviridae', 'Alphapolyomavirus', '7d', 'dsDNA', '6zlz']),
#  (7.04, ['Nanoparticles', 'Nanoparticles', '4', 'ssRNA', '7a4i']),
#  (2.87, ['Secoviridae', 'Cheravirus', 'pT3', 'ssRNA', '7chk']),
#  (2.9, ['Nanoparticles', 'Nanoparticles', '4', 'NA', '7ckc']),
#  (2.79, ['dsRNA viruses', 'Unclassified dsRNA viruses', '1', 'dsRNA', '7d0k']),
#  (2.95, ['dsRNA viruses', 'Unclassified dsRNA viruses', '1', 'dsDNA', '7d0l']),
#  (2.7, ['Podoviridae', 'Schmidvirus', '9', 'dsDNA', '7dn2']),
#  (2.9, ['Caliciviridae', 'Sapovirus', '3', 'ssRNA', '7dod']),
#  (3.26, ['Unknown', 'Unknown', '7l', 'dsDNA', '7eel']),
#  (2.4, ['Bromoviridae', 'Alfamovirus', '1', 'ssRNA', '7epp']),
#  (3.35, ['Myoviridae', 'Myovirus', '9', 'dsDNA', '7f38']),
#  (4.19, ['Myoviridae', 'Peduovirinae', '4', 'dsDNA', '7jw1']),
#  (3.2, ['Myoviridae', 'NA', '7l', 'dsDNA', '7kmx']),
#  (2.76, ['Parvoviridae', 'Bocaparvovirus', '1', 'ssRNA', '7lnk']),
#  (2.49, ['Parvoviridae', 'Dependoparovirus', '1', 'ssDNA', '7ltm']),
#  (4.0, ['Totiviridae', 'Trichomonasvirus', '1', 'dsRNA', '7m12']),
#  (2.9, ['Partitiviridae', 'Deltapartitivirus', '2', 'dsRNA', '7ncr']),
#  (3.1, ['Retroviridae', 'Virus Like Particle', '1', 'NA', '7no0']),
#  (7.6, ['Retroviridae', 'Virus Like Particle', '3', 'NA', '7no1']),
#  (4.0, ['Siphoviridae', 'Triavirus', '4', 'dsDNA', '7rwz']),
#  (3.3, ['Papillomaviridae', 'Pipapillomavirus', '7d', 'dsDNA', '7ryj']),
#  (3.4, ['Tymoviridae', 'Marafivirus', '3', 'ssRNA', '7sqy']),
#  (2.96, ['Picornaviridae', 'Enterovirus F4', 'pT3', 'ssRNA', '7thx']),
#  (5.03, ['Siphoviridae', 'Lambdavirus', '7', 'dsDNA', '7vi9'])]

# %%
reslist
# Out:
# [['Virtovirus', 'Tobacco virtovirus 1', '1', 'ssRNA', '1a34'],
#  ['Secoviridae', 'Nepovirus', 'pT3', 'ssRNA', '1a6c'],
#  ['Microviridae', 'Microvirus', '1', 'ssDNA', '1al0'],
#  ['Picornaviridae', 'Enterovirus C', 'pT3', 'ssRNA', '1al2'],
#  ['Leviviridae', 'Levivirus', '3', 'ssRNA', '1aq3'],
#  ['Tymoviridae', 'Tymovirus', '3', 'ssRNA', '1auy'],
#  ['Picornaviridae', 'Rhinovirus', 'pT3', 'ssRNA', '1aym'],
#  ['Dicistroviridae', 'Cripavirus', 'pT3', 'ssRNA', '1b35'],
#  ['Picornaviridae', 'Aphthovirus', 'pT3', 'ssRNA', '1bbt'],
#  ['Picornaviridae', 'Enterovirus', 'pT3', 'ssRNA', '1bev'],
#  ['Secoviridae', 'Comovirus', 'pT3', 'ssRNA', '1bmv'],
#  ['Parvoviridae', 'Parvovirus', '1', 'ssDNA', '1c8d'],
#  ['Tombusviridae', 'Necrovirus', '3', 'ssRNA', '1c8n'],
#  ['Bromoviridae', 'Bromovirus', '3', 'ssRNA', '1cwp'],
#  ['Parvoviridae', 'Densovirus', '1', 'ssDNA', '1dnv'],
#  ['Togaviridae', 'Alphavirus', '4', 'ssRNA', '1dyl'],
#  ['Papillomaviridae', 'Alphapapillomavirus', '1', 'dsDNA', '1dzl'],
#  ['Reoviridae', 'Orthoreovirus', '2', 'dsRNA', '1ej6'],
#  ['Bromoviridae', 'Cucumovirus', '3', 'ssRNA', '1f15'],
#  ['Sobemovirus', 'Sobemovirus', '3', 'ssRNA', '1f2n'],
#  ['Nodaviridae', 'Alphanodavirus', '3', 'ssRNA', '1f8v'],
#  ['Parvoviridae', 'Parvovirus', '1', 'ssRNA', '1fpv'],
#  ['Tectiviridae', 'Tectivirus', 'pT25', 'dsDNA', '1gw7'],
#  ['Siphoviridae', 'Lambdavirus', '7l', 'dsDNA', '1if0'],
#  ['Caliciviridae', 'Norovirus', '3', 'ssRNA', '1ihm'],
#  ['Flaviviridae', 'Flavivirus', '3', 'ssRNA', '1k4r'],
#  ['Papillomaviridae', 'Alphapapillomavirus', '7d', 'dsDNA', '1l0t'],
#  ['Parvoviridae', 'Dependoparvovirus', '1', 'ssDNA', '1lp3'],
#  ['Totiviridae', 'Totivirus', '2', 'dsRNA', '1m1c'],
#  ['Phycodnaviridae', 'Chlorovirus', 'pT169', 'dsDNA', '1m4x'],
#  ['Picornaviridae', 'Cardiovirus', 'pT3', 'ssRNA', '1mec'],
#  ['Flaviviridae', 'Flavivirus', '3', 'ssDNA', '1n6g'],
#  ['Tetraviridae', 'Omegatetravirus', '4', 'ssRNA', '1ohf'],
#  ['Tombusviridae', 'Carmovirus', '3', 'ssRNA', '1opo'],
#  ['Leviviridae', 'Allolevivirus', '3', 'ssRNA', '1qbe'],
#  ['Hepadnaviridae', 'Orthohepadnavirus', '4', 'dsDNA', '1qgt'],
#  ['Polyomaviridae', 'Polyomavirus', '7d', 'dsDNA', '1sid'],
#  ['Papanivirus', 'Panicum papanivirus 1', '1', '', '1stm'],
#  ['Reoviridae', 'Phytoreovirus', '13', 'dsRNA', '1uf2'],
#  ['Sobemovirus', 'Sobemovirus', '1', 'ssRNA', '1vak'],
#  ['Birnaviridae', 'Avibirnavirus', '1', 'dsRNA', '1wcd'],
#  ['Birnaviridae', 'Avibirnavirus', '13', 'dsRNA', '1wce'],
#  ['Adenoviridae', 'Mastadenovirus', '1', 'dsDNA', '1x9p'],
#  ['Bromoviridae', 'Bromovirus', '1', 'ssRNA', '1yc6'],
#  ['Podoviridae', 'Phi29virus', '3', 'dsDNA', '1yxn'],
#  ['Parvoviridae', 'Parvovirus', '1', '', '1z14'],
#  ['Parvoviridae', 'Protoparvovirus', '1', 'ssDNA', '1z1c'],
#  ['Reoviridae', 'Orbivirus', '13', 'dsRNA', '2btv'],
#  ['Albetovirus', 'Tobacco albetovirus 1', '1', 'ssRNA', '2buk'],
#  ['Reoviridae', 'Orthoreovirus', '13', 'dsRNA', '2cse'],
#  ['Thermococcales', 'Pyrococcus', '3', 'ssDNA', '2e0z'],
#  ['Caliciviridae', 'Vesivirus', '3', 'ssRNA', '2gh8'],
#  ['Tetraviridae', 'Betatetravirus', '4', 'ssRNA', '2qqp'],
#  ['Albetovirus', 'Tobacco albetovirus 1', '1', '', '2stv'],
#  ['Tombusviridae', 'Tombusvirus', '3', 'ssRNA', '2tbv'],
#  ['Picobirnaviridae', 'Picobirnavirus', '2', 'dsRNA', '2vf1'],
#  ['Leviviridae', 'Unclassified', '3', 'ssRNA', '2vf9'],
#  ['Corticoviridae', 'Corticovirus', 'pT21', 'dsDNA', '2w0c'],
#  ['Retroviridae', 'Alpharetrovirus', '1', 'ssRNA', '2x8q'],
#  ['Podoviridae', 'unassigned Autographivirinae', '7l', 'dsDNA', '2xd8'],
#  ['Podoviridae', 'T7virus', '7l', 'dsDNA', '2xvr'],
#  ['Podoviridae', 'P22-like viruses', '7l', 'dsDNA', '2xyy'],
#  ['Hepeviridae', 'Orthohepevirus', '1', 'ssRNA', '2ztn'],
#  ['Podoviridae', 'p22-like Viruses', '7l', 'dsDNA', '3c5b'],
#  ['Picornaviridae', 'Senecavirus', 'pT3', 'ssRNA', '3cji'],
#  ['Reoviridae', 'Cypovirus', '2', 'dsRNA', '3cnf'],
#  ['Partitiviridae', 'Partitivirus', '2', 'dsRNA', '3es5'],
#  ['Reoviridae', 'Rotavirus', '13', 'dsRNA', '3gzt'],
#  ['Reoviridae', 'Rotavirus', '', 'dsRNA', '3gzu'],
#  ['Birnaviridae', 'Aquabirnavirus', '1', 'dsRNA', '3ide'],
#  ['Podoviridae', 'P22-like Viruses', '7l', 'dsDNA', '3iyh'],
#  ['Papillomaviridae', 'Deltapapillomavirus', '7d', 'dsDNA', '3iyj'],
#  ['Reoviridae', 'Aquareovirus', '2', 'dsDNA', '3iyl'],
#  ['Hepeviridae', 'Orthohepevirus', '3', 'ssRNA', '3iyo'],
#  ['Reoviridae', 'Reovirus', '', 'dsRNA', '3iz3'],
#  ['Reoviridae', 'Cypovirus', '1', 'dsRNA', '3j17'],
#  ['Caliciviridae', 'Lagovirus', '3', 'ssRNA', '3j1p'],
#  ['Lavidaviridae', 'Sputnikvirus', 'pT27', 'dsDNA', '3j26'],
#  ['Turriviridae', 'Alphaturrivirus', 'pT31', 'dsDNA', '3j31'],
#  ['Chrysoviridae', 'Chrysovirus', '1', 'dsRNA', '3j3i'],
#  ['Podoviridae', 'Epsilon15-like', '7l', 'dsDNA', '3j40'],
#  ['Podoviridae', 'Bpp1virus', '7l', 'dsDNA', '3j4u'],
#  ['Reoviridae', 'Cypovirus', '', 'dsRNA', '3jaz'],
#  ['Picornaviridae', 'Parechovirus', 'pT3', 'ssRNA', '3jb4'],
#  ['Tombusviridae', 'Machlomovirus', '3', 'ssRNA', '3jb8'],
#  ['Nodaviridae', 'Betanodavirus', '3', 'ssRNA', '3jbm'],
#  ['Circoviridae', 'Circovirus', '1', 'ssDNA', '3jci'],
#  ['Reoviridae', 'Aquareovirus', '', 'dsDNA', '3k1q'],
#  ['Caliciviridae', 'Calicivirus', '3', 'ssRNA', '3m8l'],
#  ['Parvoviridae', 'Penstyldensovirus', '1', 'ssDNA', '3n7x'],
#  ['Adenoviridae', 'Mastadenovirus', 'pT25', 'dsDNA', '3zif'],
#  ['Cystoviridae', 'Cystovirus', '2', 'dsRNA', '4btg'],
#  ['Cystoviridae', 'Cystovirus', '13', 'dsRNA', '4btq'],
#  ['Parvoviridae', 'Ambidensovirus', '1', 'ssDNA', '4mgu'],
#  ['Nodaviridae', 'Unclassified', '3', 'ssRNA', '4nwv'],
#  ['Caliciviridae', 'Vesivirus', '1', 'ssRNA', '4pb6'],
#  ['Nanoparticles', 'Nanoparticles', '3', 'NA', '4pt2'],
#  ['Parvoviridae', 'Bocaparvovirus', '1', 'ssDNA', '4qc8'],
#  ['Picornaviridae', 'Hepatovirus', '3', 'ssRNA', '4qpg'],
#  ['Nodaviridae', 'Betanodavirus', '1', 'ssRNA', '4rft'],
#  ['Albetovirus', 'Tobacco albetovirus 1', '1', 'NA', '4v4m'],
#  ['Tombusviridae', 'Panicovirus', '3', 'ssRNA', '4v99'],
#  ['Picornaviridae', 'Enterovirus A', 'pT3', 'ssRNA', '4yvw'],
#  ['Leviviridae', 'Levivirus', '1', 'ssRNA', '4zor'],
#  ['Picornaviridae', 'Kobuvirus', 'pT3', 'ssRNA', '5aoo'],
#  ['Dicistroviridae', 'Aparavirus', 'pT3', 'ssRNA', '5cdc'],
#  ['Papanivirus', 'Panicum papanivirus 1', '1', 'ssRNA', '5cvz'],
#  ['Iflaviridae', 'Iflavirus', 'pT3', 'ssRNA', '5g52'],
#  ['Podoviridae', 'P22virus', '7l', 'dsDNA', '5l35'],
#  ['Unclassified', 'Unclassified', 'pT3', 'ssRNA', '5mm2'],
#  ['Dicistroviridae', 'Triatovirus', 'pT3', 'ssRNA', '5mqc'],
#  ['Unknown', 'Unknown', 'pT21', 'dsDNA', '5oac'],
#  ['Myoviridae', 'T4virus', '13', 'dsDNA', '5vf3'],
#  ['Picornaviridae', 'Hepatovirus', 'pT3', 'ssRNA', '5wte'],
#  ['Nodaviridae', 'Unclassified', '1', 'ssRNA', '5yl1'],
#  ['Herpesviridae', 'Alphaherpesvirinae', '16', 'dsDNA', '5zap'],
#  ['Reoviridae', 'Aquareovirus', '1', 'dsRNA', '5zvt'],
#  ['Siphoviridae', 'Phietavirus', '7l', 'dsDNA', '6b0x'],
#  ['Siphoviridae', 'Phietavirus', '4', 'dsDNA', '6b23'],
#  ['Herpesviridae', 'Rhadinovirus', '16', 'dsDNA', '6b43'],
#  ['Hepadnaviridae', 'Orthohepadnavirus', '3', 'dsDNA', '6bvn'],
#  ['Siphoviridae', 'Phietavirus', '4', 'ssDNA', '6c22'],
#  ['Adenoviridae', 'Mastadenovirus', 'pT25', 'ssDNA', '6cgv'],
#  ['Reoviridae', 'Dinovernavirus', '1', 'dsRNA', '6djy'],
#  ['Polyomaviridae', 'Betapolyomavirus', '7d', 'dsDNA', '6gg0'],
#  ['Sphaerolipoviridae', 'Alphasphaerolipovirus', '28d', 'dsDNA', '6h82'],
#  ['Siphoviridae', 'P23virus', '7l', 'dsDNA', '6i9e'],
#  ['Nanoparticles', 'Nanoparticles', '1', 'NA', '6i9g'],
#  ['Unclassified', 'Unclassified', '3', 'ssRNA', '6izl'],
#  ['Siphoviridae', 'Cyanophage Mic1', '13', 'dsDNA', '6j3q'],
#  ['Parvoviridae', 'Denpendoparvovirus', '1', 'ssDNA', '6jct'],
#  ['Sarthroviridae', 'Macronovirus', '1', 'ssRNA', '6jja'],
#  ['Nodaviridae', 'Unclassified Nodaviridae', '3', 'ssRNA', '6jjc'],
#  ['Picornaviridae', 'Enterovirus B', 'pT3', 'ssRNA', '6la3'],
#  ['Tombusviridae', 'Aureusvirus', '3', 'ssRNA', '6mrl'],
#  ['Tombusviridae', 'Dianthovirus', '3', 'ssRNA', '6mrm'],
#  ['Nanoparticles', 'Nanoparticles', '9', 'NA', '6mzx'],
#  ['Phycodnaviridae', 'Chlorovirus', '169', 'dsDNA', '6ncl'],
#  ['Parvoviridae', 'Virus Like Particle', '1', 'ssDNA', '6nf9'],
#  ['Herpesviridae', 'Muromegalovirus', '16', 'dsDNA', '6nhj'],
#  ['Parvoviridae', 'Erythroparvovirus', '1', 'ssDNA', '6nn3'],
#  ['Siphoviridae', 'Oshimavirus', '7l', 'dsDNA', '6o3h'],
#  ['Parvoviridae', 'Dependoparvovirus', '1', 'dsDNA', '6o9r'],
#  ['Protogloboviridae', 'Alphaprotoglobovirus', '43', 'dsDNA', '6oj0'],
#  ['Siphoviridae', 'Tequintavirus', '13', 'dsDNA', '6okb'],
#  ['Caliciviridae', 'Norovirus', '1', 'ssRNA', '6ouc'],
#  ['Caliciviridae', 'Norovirus', '4', 'ssRNA', '6ouu'],
#  ['Herpesviridae', 'Betaherpesvirinae', '16', 'dsDNA', '6q1f'],
#  ['Adenoviridae', 'Atadenovirus', 'pT25', 'dsDNA', '6qi5'],
#  ['Saccharomycetales', 'Saccharomyces', '9', 'ssRNA', '6r24'],
#  ['Siphoviridae', 'Unclassified Siphovirus', '7l', 'dsDNA', '6r3a'],
#  ['Leviviridae', 'Levivirus', '4', 'ssRNA', '6rrt'],
#  ['dsRNA viruses', 'Unclassified', '1', 'dsRNA', '6s2c'],
#  ['Nanoviridae', 'Nanovirus', '1', 'ssRNA', '6s44'],
#  ['Luteoviridae', 'Luteovirus', '3', 'ssRNA', '6scl'],
#  ['Luteoviridae', 'Polerovirus', '3', 'ssRNA', '6sco'],
#  ['Marnaviridae', 'Sogarnavirus', 'pT3', 'ssRNA', '6shl'],
#  ['Retroviridae', 'Unclassified', '1', 'ssRNA', '6ssj'],
#  ['Retroviridae', 'Unclassified', '3', 'ssRNA', '6ssm'],
#  ['Picornaviridae', 'Enterovirus F', 'pT3', 'ssRNA', '6t40'],
#  ['Unclassified', 'Unclassified', '4', 'NA', '6tap'],
#  ['Picornaviridae', 'Enterovirus E', 'pT3', 'ssRNA', '6thd'],
#  ['Rhodobacterales', 'Rhodobacteraceae', '3', 'NA', '6tsw'],
#  ['Herpesviridae', 'Gammaherpesvirinae', '16', 'dsDNA', '6w19'],
#  ['Picornaviridae', 'Enterovirus D', 'pT3', 'ssRNA', '6wds'],
#  ['Synechococcaceae', 'Synechococcus', '1', 'NA', '6x8m'],
#  ['Unclassified', 'Unclassified', '7l', 'dsDNA', '6xgq'],
#  ['Totiviridae', 'Leishmaniavirus', '1', 'dsRNA', '6y83'],
#  ['Leviviridae', 'MS2-like capsids', '3', 'ssRNA', '6yf7'],
#  ['Leviviridae', 'MS2-like capsids', '1', 'ssRNA', '6yfb'],
#  ['Hepadnaviridae', 'Avihepadnavirus', '4', 'dsDNA', '6ygh'],
#  ['Polyomaviridae', 'Alphapolyomavirus', '7d', 'dsDNA', '6zlz'],
#  ['Nanoparticles', 'Nanoparticles', '4', 'ssRNA', '7a4i'],
#  ['Secoviridae', 'Cheravirus', 'pT3', 'ssRNA', '7chk'],
#  ['Nanoparticles', 'Nanoparticles', '4', 'NA', '7ckc'],
#  ['dsRNA viruses', 'Unclassified dsRNA viruses', '1', 'dsRNA', '7d0k'],
#  ['dsRNA viruses', 'Unclassified dsRNA viruses', '1', 'dsDNA', '7d0l'],
#  ['Podoviridae', 'Schmidvirus', '9', 'dsDNA', '7dn2'],
#  ['Caliciviridae', 'Sapovirus', '3', 'ssRNA', '7dod'],
#  ['Unknown', 'Unknown', '7l', 'dsDNA', '7eel'],
#  ['Bromoviridae', 'Alfamovirus', '1', 'ssRNA', '7epp'],
#  ['Myoviridae', 'Myovirus', '9', 'dsDNA', '7f38'],
#  ['Myoviridae', 'Peduovirinae', '4', 'dsDNA', '7jw1'],
#  ['Myoviridae', 'NA', '7l', 'dsDNA', '7kmx'],
#  ['Parvoviridae', 'Bocaparvovirus', '1', 'ssRNA', '7lnk'],
#  ['Parvoviridae', 'Dependoparovirus', '1', 'ssDNA', '7ltm'],
#  ['Totiviridae', 'Trichomonasvirus', '1', 'dsRNA', '7m12'],
#  ['Partitiviridae', 'Deltapartitivirus', '2', 'dsRNA', '7ncr'],
#  ['Retroviridae', 'Virus Like Particle', '1', 'NA', '7no0'],
#  ['Retroviridae', 'Virus Like Particle', '3', 'NA', '7no1'],
#  ['Siphoviridae', 'Triavirus', '4', 'dsDNA', '7rwz'],
#  ['Papillomaviridae', 'Pipapillomavirus', '7d', 'dsDNA', '7ryj'],
#  ['Tymoviridae', 'Marafivirus', '3', 'ssRNA', '7sqy'],
#  ['Picornaviridae', 'Enterovirus F4', 'pT3', 'ssRNA', '7thx'],
#  ['Siphoviridae', 'Lambdavirus', '7', 'dsDNA', '7vi9']]

# %%
lres = []
for el in reslist:
    b = find_best(res_tups, el)
    if b not in lres: lres.append(b)

# %%
columns = ['family', 'genus', 'tnumber', 'genome', 'id', 'resolution']

# %%
dfdict = {}

# %%
lres
# Out:
# [['Virtovirus', 'Tobacco virtovirus 1', '1', 'ssRNA', '1a34', 1.81],
#  ['Secoviridae', 'Nepovirus', 'pT3', 'ssRNA', '1a6c', 3.5],
#  ['Microviridae', 'Microvirus', '1', 'ssDNA', '1al0', 3.5],
#  ['Picornaviridae', 'Enterovirus C', 'pT3', 'ssRNA', '1al2', 2.9],
#  ['Leviviridae', 'Levivirus', '3', 'ssRNA', '1aq3', 2.8],
#  ['Tymoviridae', 'Tymovirus', '3', 'ssRNA', '1auy', 3.2],
#  ['Picornaviridae', 'Rhinovirus', 'pT3', 'ssRNA', '1aym', 2.15],
#  ['Dicistroviridae', 'Cripavirus', 'pT3', 'ssRNA', '1b35', 2.4],
#  ['Picornaviridae', 'Aphthovirus', 'pT3', 'ssRNA', '1bbt', 2.6],
#  ['Picornaviridae', 'Enterovirus', 'pT3', 'ssRNA', '1bev', 3.0],
#  ['Secoviridae', 'Comovirus', 'pT3', 'ssRNA', '1bmv', 3.0],
#  ['Parvoviridae', 'Parvovirus', '1', 'ssDNA', '1c8d', 3.0],
#  ['Tombusviridae', 'Necrovirus', '3', 'ssRNA', '1c8n', 2.25],
#  ['Bromoviridae', 'Bromovirus', '3', 'ssRNA', '1cwp', 3.2],
#  ['Parvoviridae', 'Densovirus', '1', 'ssDNA', '1dnv', 3.6],
#  ['Togaviridae', 'Alphavirus', '4', 'ssRNA', '1dyl', 9.0],
#  ['Papillomaviridae', 'Alphapapillomavirus', '1', 'dsDNA', '1dzl', 3.5],
#  ['Reoviridae', 'Orthoreovirus', '2', 'dsRNA', '1ej6', 3.6],
#  ['Bromoviridae', 'Cucumovirus', '3', 'ssRNA', '1f15', 3.2],
#  ['Sobemovirus', 'Sobemovirus', '3', 'ssRNA', '1f2n', 2.8],
#  ['Nodaviridae', 'Alphanodavirus', '3', 'ssRNA', '1f8v', 3.0],
#  ['Parvoviridae', 'Parvovirus', '1', 'ssRNA', '1fpv', 3.3],
#  ['Tectiviridae', 'Tectivirus', 'pT25', 'dsDNA', '1gw7', 13.5],
#  ['Siphoviridae', 'Lambdavirus', '7l', 'dsDNA', '1if0', 12.0],
#  ['Caliciviridae', 'Norovirus', '3', 'ssRNA', '1ihm', 3.4],
#  ['Flaviviridae', 'Flavivirus', '3', 'ssRNA', '1k4r', 24.0],
#  ['Papillomaviridae', 'Alphapapillomavirus', '7d', 'dsDNA', '1l0t', 999.0],
#  ['Parvoviridae', 'Dependoparvovirus', '1', 'ssDNA', '1lp3', 3.0],
#  ['Totiviridae', 'Totivirus', '2', 'dsRNA', '1m1c', 3.5],
#  ['Phycodnaviridae', 'Chlorovirus', 'pT169', 'dsDNA', '1m4x', 28.0],
#  ['Picornaviridae', 'Cardiovirus', 'pT3', 'ssRNA', '1mec', 3.2],
#  ['Flaviviridae', 'Flavivirus', '3', 'ssDNA', '1n6g', 16.0],
#  ['Tetraviridae', 'Omegatetravirus', '4', 'ssRNA', '1ohf', 2.8],
#  ['Tombusviridae', 'Carmovirus', '3', 'ssRNA', '1opo', 3.2],
#  ['Leviviridae', 'Allolevivirus', '3', 'ssRNA', '1qbe', 3.5],
#  ['Hepadnaviridae', 'Orthohepadnavirus', '4', 'dsDNA', '1qgt', 3.3],
#  ['Polyomaviridae', 'Polyomavirus', '7d', 'dsDNA', '1sid', 3.65],
#  ['Papanivirus', 'Panicum papanivirus 1', '1', '', '1stm', 1.9],
#  ['Reoviridae', 'Phytoreovirus', '13', 'dsRNA', '1uf2', 3.5],
#  ['Sobemovirus', 'Sobemovirus', '1', 'ssRNA', '1vak', 3.05],
#  ['Birnaviridae', 'Avibirnavirus', '1', 'dsRNA', '1wcd', 3.0],
#  ['Birnaviridae', 'Avibirnavirus', '13', 'dsRNA', '1wce', 7.0],
#  ['Adenoviridae', 'Mastadenovirus', '1', 'dsDNA', '1x9p', 3.3],
#  ['Bromoviridae', 'Bromovirus', '1', 'ssRNA', '1yc6', 2.9],
#  ['Podoviridae', 'Phi29virus', '3', 'dsDNA', '1yxn', 7.9],
#  ['Parvoviridae', 'Parvovirus', '1', '', '1z14', 3.25],
#  ['Parvoviridae', 'Protoparvovirus', '1', 'ssDNA', '1z1c', 3.5],
#  ['Reoviridae', 'Orbivirus', '13', 'dsRNA', '2btv', 3.5],
#  ['Albetovirus', 'Tobacco albetovirus 1', '1', 'ssRNA', '2buk', 2.45],
#  ['Reoviridae', 'Orthoreovirus', '13', 'dsRNA', '2cse', 7.0],
#  ['Thermococcales', 'Pyrococcus', '3', 'ssDNA', '2e0z', 3.6],
#  ['Caliciviridae', 'Vesivirus', '3', 'ssRNA', '2gh8', 3.2],
#  ['Tetraviridae', 'Betatetravirus', '4', 'ssRNA', '2qqp', 3.8],
#  ['Albetovirus', 'Tobacco albetovirus 1', '1', '', '2stv', 2.5],
#  ['Tombusviridae', 'Tombusvirus', '3', 'ssRNA', '2tbv', 2.9],
#  ['Picobirnaviridae', 'Picobirnavirus', '2', 'dsRNA', '2vf1', 3.4],
#  ['Leviviridae', 'Unclassified', '3', 'ssRNA', '2vf9', 3.5],
#  ['Corticoviridae', 'Corticovirus', 'pT21', 'dsDNA', '2w0c', 7.0],
#  ['Retroviridae', 'Alpharetrovirus', '1', 'ssRNA', '2x8q', 18.3],
#  ['Podoviridae', 'unassigned Autographivirinae', '7l', 'dsDNA', '2xd8', 4.6],
#  ['Podoviridae', 'T7virus', '7l', 'dsDNA', '2xvr', 10.8],
#  ['Podoviridae', 'P22-like viruses', '7l', 'dsDNA', '2xyy', 3.8],
#  ['Hepeviridae', 'Orthohepevirus', '1', 'ssRNA', '2ztn', 3.56],
#  ['Podoviridae', 'p22-like Viruses', '7l', 'dsDNA', '3c5b', 4.5],
#  ['Picornaviridae', 'Senecavirus', 'pT3', 'ssRNA', '3cji', 2.3],
#  ['Reoviridae', 'Cypovirus', '2', 'dsRNA', '3cnf', 3.88],
#  ['Partitiviridae', 'Partitivirus', '2', 'dsRNA', '3es5', 3.3],
#  ['Reoviridae', 'Rotavirus', '13', 'dsRNA', '3gzt', 3.8],
#  ['Reoviridae', 'Rotavirus', '', 'dsRNA', '3gzu', 3.8],
#  ['Birnaviridae', 'Aquabirnavirus', '1', 'dsRNA', '3ide', 3.35],
#  ['Podoviridae', 'P22-like Viruses', '7l', 'dsDNA', '3iyh', 8.2],
#  ['Papillomaviridae', 'Deltapapillomavirus', '7d', 'dsDNA', '3iyj', 4.2],
#  ['Reoviridae', 'Aquareovirus', '2', 'dsDNA', '3iyl', 3.3],
#  ['Hepeviridae', 'Orthohepevirus', '3', 'ssRNA', '3iyo', 10.5],
#  ['Reoviridae', 'Reovirus', '', 'dsRNA', '3iz3', 3.9],
#  ['Reoviridae', 'Cypovirus', '1', 'dsRNA', '3j17', 4.1],
#  ['Caliciviridae', 'Lagovirus', '3', 'ssRNA', '3j1p', 6.5],
#  ['Lavidaviridae', 'Sputnikvirus', 'pT27', 'dsDNA', '3j26', 3.5],
#  ['Turriviridae', 'Alphaturrivirus', 'pT31', 'dsDNA', '3j31', 4.5],
#  ['Chrysoviridae', 'Chrysovirus', '1', 'dsRNA', '3j3i', 4.1],
#  ['Podoviridae', 'Epsilon15-like', '7l', 'dsDNA', '3j40', 4.5],
#  ['Podoviridae', 'Bpp1virus', '7l', 'dsDNA', '3j4u', 3.5],
#  ['Reoviridae', 'Cypovirus', '', 'dsRNA', '3jaz', 3.1],
#  ['Picornaviridae', 'Parechovirus', 'pT3', 'ssRNA', '3jb4', 3.8],
#  ['Tombusviridae', 'Machlomovirus', '3', 'ssRNA', '3jb8', 3.6],
#  ['Nodaviridae', 'Betanodavirus', '3', 'ssRNA', '3jbm', 3.9],
#  ['Circoviridae', 'Circovirus', '1', 'ssDNA', '3jci', 2.9],
#  ['Reoviridae', 'Aquareovirus', '', 'dsDNA', '3k1q', 4.5],
#  ['Caliciviridae', 'Calicivirus', '3', 'ssRNA', '3m8l', 3.4],
#  ['Parvoviridae', 'Penstyldensovirus', '1', 'ssDNA', '3n7x', 2.5],
#  ['Adenoviridae', 'Mastadenovirus', 'pT25', 'dsDNA', '3zif', 4.5],
#  ['Cystoviridae', 'Cystovirus', '2', 'dsRNA', '4btg', 4.4],
#  ['Cystoviridae', 'Cystovirus', '13', 'dsRNA', '4btq', 7.5],
#  ['Parvoviridae', 'Ambidensovirus', '1', 'ssDNA', '4mgu', 3.5],
#  ['Nodaviridae', 'Unclassified', '3', 'ssRNA', '4nwv', 3.25],
#  ['Caliciviridae', 'Vesivirus', '1', 'ssRNA', '4pb6', 8.0],
#  ['Nanoparticles', 'Nanoparticles', '3', 'NA', '4pt2', 4.6],
#  ['Parvoviridae', 'Bocaparvovirus', '1', 'ssDNA', '4qc8', 3.2],
#  ['Picornaviridae', 'Hepatovirus', '3', 'ssRNA', '4qpg', 3.5],
#  ['Nodaviridae', 'Betanodavirus', '1', 'ssRNA', '4rft', 3.1],
#  ['Albetovirus', 'Tobacco albetovirus 1', '1', 'NA', '4v4m', 1.45],
#  ['Tombusviridae', 'Panicovirus', '3', 'ssRNA', '4v99', 2.9],
#  ['Picornaviridae', 'Enterovirus A', 'pT3', 'ssRNA', '4yvw', 3.8],
#  ['Leviviridae', 'Levivirus', '1', 'ssRNA', '4zor', 2.2],
#  ['Picornaviridae', 'Kobuvirus', 'pT3', 'ssRNA', '5aoo', 2.1],
#  ['Dicistroviridae', 'Aparavirus', 'pT3', 'ssRNA', '5cdc', 4.0],
#  ['Papanivirus', 'Panicum papanivirus 1', '1', 'ssRNA', '5cvz', 3.3],
#  ['Iflaviridae', 'Iflavirus', 'pT3', 'ssRNA', '5g52', 3.8],
#  ['Podoviridae', 'P22virus', '7l', 'dsDNA', '5l35', 2.89],
#  ['Unclassified', 'Unclassified', 'pT3', 'ssRNA', '5mm2', 2.7],
#  ['Dicistroviridae', 'Triatovirus', 'pT3', 'ssRNA', '5mqc', 3.4],
#  ['Unknown', 'Unknown', 'pT21', 'dsDNA', '5oac', 4.0],
#  ['Myoviridae', 'T4virus', '13', 'dsDNA', '5vf3', 3.3],
#  ['Picornaviridae', 'Hepatovirus', 'pT3', 'ssRNA', '5wte', 3.4],
#  ['Nodaviridae', 'Unclassified', '1', 'ssRNA', '5yl1', 3.12],
#  ['Herpesviridae', 'Alphaherpesvirinae', '16', 'dsDNA', '5zap', 3.1],
#  ['Reoviridae', 'Aquareovirus', '1', 'dsRNA', '5zvt', 3.3],
#  ['Siphoviridae', 'Phietavirus', '7l', 'dsDNA', '6b0x', 3.8],
#  ['Siphoviridae', 'Phietavirus', '4', 'dsDNA', '6b23', 3.7],
#  ['Herpesviridae', 'Rhadinovirus', '16', 'dsDNA', '6b43', 4.2],
#  ['Hepadnaviridae', 'Orthohepadnavirus', '3', 'dsDNA', '6bvn', 4.0],
#  ['Siphoviridae', 'Phietavirus', '4', 'ssDNA', '6c22', 8.4],
#  ['Adenoviridae', 'Mastadenovirus', 'pT25', 'ssDNA', '6cgv', 3.8],
#  ['Reoviridae', 'Dinovernavirus', '1', 'dsRNA', '6djy', 3.9],
#  ['Polyomaviridae', 'Betapolyomavirus', '7d', 'dsDNA', '6gg0', 4.24],
#  ['Sphaerolipoviridae', 'Alphasphaerolipovirus', '28d', 'dsDNA', '6h82', 3.78],
#  ['Siphoviridae', 'P23virus', '7l', 'dsDNA', '6i9e', 3.74],
#  ['Nanoparticles', 'Nanoparticles', '1', 'NA', '6i9g', 2.5],
#  ['Unclassified', 'Unclassified', '3', 'ssRNA', '6izl', 3.3],
#  ['Siphoviridae', 'Cyanophage Mic1', '13', 'dsDNA', '6j3q', 3.53],
#  ['Parvoviridae', 'Denpendoparvovirus', '1', 'ssDNA', '6jct', 3.18],
#  ['Sarthroviridae', 'Macronovirus', '1', 'ssRNA', '6jja', 2.91],
#  ['Nodaviridae', 'Unclassified Nodaviridae', '3', 'ssRNA', '6jjc', 2.92],
#  ['Picornaviridae', 'Enterovirus B', 'pT3', 'ssRNA', '6la3', 2.32],
#  ['Tombusviridae', 'Aureusvirus', '3', 'ssRNA', '6mrl', 3.2],
#  ['Tombusviridae', 'Dianthovirus', '3', 'ssRNA', '6mrm', 2.9],
#  ['Nanoparticles', 'Nanoparticles', '9', 'NA', '6mzx', 3.0],
#  ['Phycodnaviridae', 'Chlorovirus', '169', 'dsDNA', '6ncl', 3.5],
#  ['Parvoviridae', 'Virus Like Particle', '1', 'ssDNA', '6nf9', 3.89],
#  ['Herpesviridae', 'Muromegalovirus', '16', 'dsDNA', '6nhj', 5.0],
#  ['Parvoviridae', 'Erythroparvovirus', '1', 'ssDNA', '6nn3', 3.22],
#  ['Siphoviridae', 'Oshimavirus', '7l', 'dsDNA', '6o3h', 2.8],
#  ['Parvoviridae', 'Dependoparvovirus', '1', 'dsDNA', '6o9r', 2.75],
#  ['Protogloboviridae', 'Alphaprotoglobovirus', '43', 'dsDNA', '6oj0', 3.7],
#  ['Siphoviridae', 'Tequintavirus', '13', 'dsDNA', '6okb', 6.7],
#  ['Caliciviridae', 'Norovirus', '1', 'ssRNA', '6ouc', 2.8],
#  ['Caliciviridae', 'Norovirus', '4', 'ssRNA', '6ouu', 4.1],
#  ['Herpesviridae', 'Betaherpesvirinae', '16', 'dsDNA', '6q1f', 9.0],
#  ['Adenoviridae', 'Atadenovirus', 'pT25', 'dsDNA', '6qi5', 3.4],
#  ['Saccharomycetales', 'Saccharomyces', '9', 'ssRNA', '6r24', 7.5],
#  ['Siphoviridae', 'Unclassified Siphovirus', '7l', 'dsDNA', '6r3a', 4.0],
#  ['Leviviridae', 'Levivirus', '4', 'ssRNA', '6rrt', 6.0],
#  ['dsRNA viruses', 'Unclassified', '1', 'dsRNA', '6s2c', 3.2],
#  ['Nanoviridae', 'Nanovirus', '1', 'ssRNA', '6s44', 3.19],
#  ['Luteoviridae', 'Luteovirus', '3', 'ssRNA', '6scl', 3.0],
#  ['Luteoviridae', 'Polerovirus', '3', 'ssRNA', '6sco', 3.3],
#  ['Marnaviridae', 'Sogarnavirus', 'pT3', 'ssRNA', '6shl', 3.1],
#  ['Retroviridae', 'Unclassified', '1', 'ssRNA', '6ssj', 2.75],
#  ['Retroviridae', 'Unclassified', '3', 'ssRNA', '6ssm', 4.34],
#  ['Picornaviridae', 'Enterovirus F', 'pT3', 'ssRNA', '6t40', 1.67],
#  ['Unclassified', 'Unclassified', '4', 'NA', '6tap', 3.5],
#  ['Picornaviridae', 'Enterovirus E', 'pT3', 'ssRNA', '6thd', 2.23],
#  ['Rhodobacterales', 'Rhodobacteraceae', '3', 'NA', '6tsw', 4.03],
#  ['Herpesviridae', 'Gammaherpesvirinae', '16', 'dsDNA', '6w19', 5.5],
#  ['Picornaviridae', 'Enterovirus D', 'pT3', 'ssRNA', '6wds', 2.9],
#  ['Synechococcaceae', 'Synechococcus', '1', 'NA', '6x8m', 2.2],
#  ['Unclassified', 'Unclassified', '7l', 'dsDNA', '6xgq', 3.8],
#  ['Totiviridae', 'Leishmaniavirus', '1', 'dsRNA', '6y83', 3.65],
#  ['Leviviridae', 'MS2-like capsids', '3', 'ssRNA', '6yf7', 3.4],
#  ['Leviviridae', 'MS2-like capsids', '1', 'ssRNA', '6yfb', 3.59],
#  ['Hepadnaviridae', 'Avihepadnavirus', '4', 'dsDNA', '6ygh', 3.7],
#  ['Polyomaviridae', 'Alphapolyomavirus', '7d', 'dsDNA', '6zlz', 3.52],
#  ['Nanoparticles', 'Nanoparticles', '4', 'ssRNA', '7a4i', 7.04],
#  ['Secoviridae', 'Cheravirus', 'pT3', 'ssRNA', '7chk', 2.87],
#  ['Nanoparticles', 'Nanoparticles', '4', 'NA', '7ckc', 2.9],
#  ['dsRNA viruses', 'Unclassified dsRNA viruses', '1', 'dsRNA', '7d0k', 2.79],
#  ['dsRNA viruses', 'Unclassified dsRNA viruses', '1', 'dsDNA', '7d0l', 2.95],
#  ['Podoviridae', 'Schmidvirus', '9', 'dsDNA', '7dn2', 2.7],
#  ['Caliciviridae', 'Sapovirus', '3', 'ssRNA', '7dod', 2.9],
#  ['Unknown', 'Unknown', '7l', 'dsDNA', '7eel', 3.26],
#  ['Bromoviridae', 'Alfamovirus', '1', 'ssRNA', '7epp', 2.4],
#  ['Myoviridae', 'Myovirus', '9', 'dsDNA', '7f38', 3.35],
#  ['Myoviridae', 'Peduovirinae', '4', 'dsDNA', '7jw1', 4.19],
#  ['Myoviridae', 'NA', '7l', 'dsDNA', '7kmx', 3.2],
#  ['Parvoviridae', 'Bocaparvovirus', '1', 'ssRNA', '7lnk', 2.76],
#  ['Parvoviridae', 'Dependoparovirus', '1', 'ssDNA', '7ltm', 2.49],
#  ['Totiviridae', 'Trichomonasvirus', '1', 'dsRNA', '7m12', 4.0],
#  ['Partitiviridae', 'Deltapartitivirus', '2', 'dsRNA', '7ncr', 2.9],
#  ['Retroviridae', 'Virus Like Particle', '1', 'NA', '7no0', 3.1],
#  ['Retroviridae', 'Virus Like Particle', '3', 'NA', '7no1', 7.6],
#  ['Siphoviridae', 'Triavirus', '4', 'dsDNA', '7rwz', 4.0],
#  ['Papillomaviridae', 'Pipapillomavirus', '7d', 'dsDNA', '7ryj', 3.3],
#  ['Tymoviridae', 'Marafivirus', '3', 'ssRNA', '7sqy', 3.4],
#  ['Picornaviridae', 'Enterovirus F4', 'pT3', 'ssRNA', '7thx', 2.96],
#  ['Siphoviridae', 'Lambdavirus', '7', 'dsDNA', '7vi9', 5.03]]

# %%
for i in range((len(columns))):
    es = [e[i] for e in lres]
    dfdict[columns[i]] = es

# %%
len(df)

# %%
from openpyxl import Workbook
from openpyxl import load_workbook
import pandas as pd

xl_file = 'unique_lres.xlsx'
wb = Workbook()
ws =  wb.active
wb.save(filename = xl_file)
book = load_workbook(xl_file)
writer = pd.ExcelWriter(xl_file, engine = 'openpyxl')
writer.book = book
df = pd.DataFrame(dfdict)
df.to_excel(writer, index = False)
book.save(xl_file)
